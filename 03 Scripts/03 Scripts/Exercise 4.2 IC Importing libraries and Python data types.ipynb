# %% [markdown]
# # 4. Importing Libraries

# %% [markdown]
# ## List of content
# 5. Importing Libraries
# 6. Python Data Types

# %%
# 5. Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 6. Python Data Types

# %%
# 7.1 First equation to get to 100:
50+50
# Out:
# 100

# %%
# 7.2 Second equation to get to 100:
150-50
# Out:
# 100

# %%
# 7.3 Third equation to get to 100:
20*5
# Out:
# 100

# %%
# 8.
a=13.675

# %%
b=170.56

# %%
type(a),type(b)
# Out:
# (float, float)

# %%
a/b
# Out:
# 0.08017706378986868

# %%
# 9.
'Career '+'Foundry'
# Out:
# 'Career Foundry'

# %%
# 10.
x='Python: Where simplicity meets power'

# %%
y='—because coding shouldn’t feel like wrestling with semicolons!'

# %%
type(x),type(y)
# Out:
# (str, str)

# %%
x+y
# Out:
# 'Python: Where simplicity meets power—because coding shouldn’t feel like wrestling with semicolons!'

# %%
z='bonus task😊 '

# %%
z*100
# Out:
# 'bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 bonus task😊 b
# ...
