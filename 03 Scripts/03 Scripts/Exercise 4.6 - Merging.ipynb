# %% [markdown]
# # Exercise 4.6 - Merging

# %% [markdown]
# ## List of contents
# 1. Libraries
# 2. Data Sets
# 3. Task
#
# 3.1.Merging Data Sets

# %% [markdown]
# ## 1. Libraries

# %%
# libraries import

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Data Sets

# %%
# creating path

# %%
path=r'/Users/konstant/Documents/Achievement 4. Instacart Basket Analysis'

# %%
df_ords_prior= pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
df_ords_checked= pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = 0)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords_checked.shape
# Out:
# (3421083, 6)

# %% [markdown]
# # 3. Task

# %% [markdown]
# ## 3.1 Merging Data Sets

# %%
# Checking the headings of both data frames.

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_checked.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_of_purchase  \
# 0   2539329        1             1                   2                 8
# 1   2398795        1             2                   3                 7
# 2    473747        1             3                   3                12
# 3   2254736        1             4                   4                 7
# 4    431534        1             5                   4                15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Checking the shape of both data frames.

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords_checked.shape
# Out:
# (3421083, 6)

# %%
#Testing the merger without overwriting the set.

# %%
pd.merge(df_ords_checked,df_ords_prior, on = ['order_id',], indicator = True)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           hour_of_purchase  days_since_prior_order  product_id  \
# 0                        8                     NaN         196
# 1                        8                     NaN       14084
# ...

# %% [markdown]
# # 1. Proceeding to merge.

# %%
# merging with the key: 'order_id', without the indicator

# %%
df_merged_large = df_ords_checked.merge(df_ords_prior, on = 'order_id')

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_of_purchase  \
# 0   2539329        1             1                   2                 8
# 1   2539329        1             1                   2                 8
# 2   2539329        1             1                   2                 8
# 3   2539329        1             1                   2                 8
# 4   2539329        1             1                   2                 8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
df_merged_large.shape
# Out:
# (32434489, 9)

# %% [markdown]
# # 2. Exporting the merged file in pickle format.

# %%
df_merged_large.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_combined.pkl'))
