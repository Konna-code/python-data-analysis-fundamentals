# %% [markdown]
# # Exercise 4.9 - part 1.

# %% [markdown]
# ## Table of content
# 3.1 Importing Libraries
#
# 3.2 Importing Data Sets
#
# 4. Data Wrangling
# 5. Data quality and consistency checks
# 6. Merging data frames
# 7. Exporting Data Frame

# %% [markdown]
# ## 3.1. Importing Libraries

# %%
#Importing analysis libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 3.2. Importing Data Sets

# %%
# Creating path

# %%
path = r'/Users/konstant/Documents/Achievement 4. Instacart Basket Analysis'

# %%
# Importing 'Customer Data' set

# %%
df_customers= pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers 2.csv'), index_col = False)

# %%
df_customers.shape
# Out:
# (206209, 10)

# %% [markdown]
# ### Exploring the 'customers' data set.

# %%
# Checking the column headers

# %%
df_customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Checkign the shape of the data frame

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# ### 206,209 rows, 10 columns. The data type is a mix of numbers (int64) and textual (object).

# %% [markdown]
# # 4. Data Wrangling

# %%
# Checking headers to rename.

# %%
df_customers.head(2)
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285

# %% [markdown]
# ## Renaming columns to keep the formatting uniform:

# %%
# Renaming the column 'First Name' to 'first_name'

# %%
df_customers.rename(columns={'First Name':'first_name'},inplace=True)

# %%
# Renaming the column 'Surname' to 'last_name'

# %%
df_customers.rename(columns={'Surnam':'last_name'},inplace=True)

# %%
# Renaming column 'Gender' to 'gender'

# %%
df_customers.rename(columns={'Gender':'gender'},inplace=True)

# %%
# Renaming column 'STATE' to 'state'

# %%
df_customers.rename(columns={'STATE':'state'},inplace=True)

# %%
# Renaming column 'Age' to 'age'

# %%
df_customers.rename(columns={'Age':'age'},inplace=True)

# %%
# Renaming column 'n_dependants' to 'num_of_dependants'

# %%
df_customers.rename(columns={'n_dependants':'num_of_dependants'},inplace=True)

# %%
# Checking results of the renaming

# %%
df_customers.head(2)
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
#
#    num_of_dependants fam_status  income
# 0                  3    married  165665
# 1                  0     single   59285

# %% [markdown]
# # 5. Data quality and consistency checks

# %% [markdown]
# ## Checking the basic statistical analyis of the data frame:

# %%
df_customers.describe(pd.set_option('display.float_format', '{:.2f}'.format)
)
# Out:
#         user_id       age  num_of_dependants    income
# count 206209.00 206209.00          206209.00 206209.00
# mean  103105.00     49.50               1.50  94632.85
# std    59527.56     18.48               1.12  42473.79
# min        1.00     18.00               0.00  25903.00
# 25%    51553.00     33.00               0.00  59874.00
# 50%   103105.00     49.00               1.00  93547.00
# 75%   154657.00     66.00               3.00 124244.00
# max   206209.00     81.00               3.00 593901.00

# %% [markdown]
# ### -The discriptive statistics looks normal.

# %% [markdown]
# ## Checking for mixed data types

# %%
# Now checking for mixed data types

# %%
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].map(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col)
# Out:
# first_name

# %% [markdown]
# ### -Mixed data type identified in the column:'first_name'

# %% [markdown]
# ### -Addressing the mixed data type column.

# %%
df_customers['first_name'] = df_customers['first_name'].astype('str')

# %%
# checking if the deployment was successul:

# %%
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].map(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col)

# %% [markdown]
# ### -There seems to be no mixed data types left.

# %% [markdown]
# ## Checking for missing values

# %%
# Now checking for missing values:

# %%
df_customers.isnull().sum()
# Out:
# user_id              0
# first_name           0
# last_name            0
# gender               0
# state                0
# age                  0
# date_joined          0
# num_of_dependants    0
# fam_status           0
# income               0
# dtype: int64

# %% [markdown]
# ### -No missing values identified

# %% [markdown]
# ## Checking for duplicated values

# %%
# Now checking for duplicated values.

# %%
df_customers[df_customers.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, num_of_dependants, fam_status, income]
# Index: []

# %% [markdown]
# ### -No duplicated values found.

# %% [markdown]
# # 6. Merging data frames

# %%
#Importing 'ords_prods_merge_aggregated_variables' data set

# %%
df_ords_prods_merge_aggregated_variables= pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_aggregated_variables.pkl'))

# %%
#Checking the column heads

# %%
df_ords_prods_merge_aggregated_variables.head(2)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19    5.80
# 1           1  Chocolate Sandwich Cookies        61             19    5.80
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_purchase  ...  \
# 0   3139998      138            28                   6                11  ...
# 1   1977647      138            30                   6                17  ...
#
#    _merge    price_range_loc  busiest_days busiest_period_of_day max_order  \
# 0    both  Mid-range product  Regular days          Most orders,        32
# 1    both  Mid-range product  Regular days       Average orders,        32
#
#        loyalty_flag max_spend  spending_flag days_since_last_order_median  \
# 0  Regular customer     20.00   High spender                         8.00
# 1  Regular customer     20.00   High spender                         8.00
#
#    order_frequency_flag
# ...

# %%
# Dropping the indicator column (_merge) that already exists on the data frame

# %%
df_ords_prods_merge_aggregated_variables.drop(columns=['_merge'],inplace=True,errors='ignore')

# %%
# Merging the 'customers' data frame with the 'ords_prods_merge_aggregated_variables'

# %%
df_final_merge=df_ords_prods_merge_aggregated_variables.merge(df_customers,on=['user_id'],indicator=True)

# %%
# Checking th results of the merge.

# %%
df_final_merge.head(2)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19    5.80
# 1           1  Chocolate Sandwich Cookies        61             19    5.80
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_purchase  ...  \
# 0   3139998      138            28                   6                11  ...
# 1   1977647      138            30                   6                17  ...
#
#    first_name  last_name  gender      state age date_joined  \
# 0     Charles        Cox    Male  Minnesota  81    8/1/2019
# 1     Charles        Cox    Male  Minnesota  81    8/1/2019
#
#    num_of_dependants fam_status  income _merge
# 0                  1    married   49620   both
# 1                  1    married   49620   both
#
# [2 rows x 32 columns]

# %% [markdown]
# # 8. Exporting Data Frame

# %%
# exporting the data frame as a pickel file.

# %%
df_final_merge.to_pickle(os.path.join(path,'02 Data','Prepared Data','df_final_merge.pkl'))
