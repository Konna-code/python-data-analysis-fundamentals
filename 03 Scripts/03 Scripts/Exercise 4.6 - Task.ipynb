# %% [markdown]
# # Exercise 4.6 - Task

# %% [markdown]
# ## Libraries

# %%
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Data Sets

# %%
#creating path

# %%
path=r'/Users/konstant/Documents/Achievement 4. Instacart Basket Analysis'

# %% [markdown]
# # 3. Importing Data Set.

# %%
df_orders_products_combined=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # 4. Checking the shape of the data frame.

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 9)

# %% [markdown]
# ## The data shape matches the shape of the exported data frame.

# %% [markdown]
# # 5. Combining 'df_orders_products_combined' with the 'products_checked' data set.

# %%
# Firstly importing 'products_checked'

# %%
df_products_checked= pd.read_csv(os.path.join(path,'02 Data','Prepared Data','products_checked.csv'),index_col = 0)

# %%
# Now checking the headings of both data frames for a merger key.

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_of_purchase  \
# 0   2539329        1             1                   2                 8
# 1   2539329        1             1                   2                 8
# 2   2539329        1             1                   2                 8
# 3   2539329        1             1                   2                 8
# 4   2539329        1             1                   2                 8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
df_products_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# 'product_id' identified as the key. Proceeding to merge with a inner join.

# %%
df_ords_prods_merge=df_products_checked.merge(df_orders_products_combined,on=['product_id'],indicator=True)

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_purchase  \
# 0   3139998      138            28                   6                11
# 1   1977647      138            30                   6                17
# 2    389851      709             2                   0                21
# 3    652770      764             1                   3                13
# 4   1813452      764             3                   4                17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge
# ...

# %% [markdown]
# # 6. Confirming the results of the merge with the merge flag.

# %%
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # 7. Exporting dataframe.

# %% [markdown]
# ## Exporting in pickle format due to it‘s size.

# %%
df_ords_prods_merge.to_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 14)
